# %% [markdown]
# # 统计作图
#
# 黄荣贵（复旦大学社会学系）

# %% [markdown]
# ### anscombe四组数据

# %%
example(anscombe)
# Out:
# anscmb> require(stats); require(graphics)
#
# anscmb> summary(anscombe)
#        x1             x2             x3             x4           y1
#  Min.   : 4.0   Min.   : 4.0   Min.   : 4.0   Min.   : 8   Min.   : 4.260
#  1st Qu.: 6.5   1st Qu.: 6.5   1st Qu.: 6.5   1st Qu.: 8   1st Qu.: 6.315
#  Median : 9.0   Median : 9.0   Median : 9.0   Median : 8   Median : 7.580
#  Mean   : 9.0   Mean   : 9.0   Mean   : 9.0   Mean   : 9   Mean   : 7.501
#  3rd Qu.:11.5   3rd Qu.:11.5   3rd Qu.:11.5   3rd Qu.: 8   3rd Qu.: 8.570
#  Max.   :14.0   Max.   :14.0   Max.   :14.0   Max.   :19   Max.   :10.840
#        y2              y3              y4
#  Min.   :3.100   Min.   : 5.39   Min.   : 5.250
#  1st Qu.:6.695   1st Qu.: 6.25   1st Qu.: 6.170
#  Median :8.140   Median : 7.11   Median : 7.040
#  Mean   :7.501   Mean   : 7.50   Mean   : 7.501
#  3rd Qu.:8.950   3rd Qu.: 7.98   3rd Qu.: 8.190
#  Max.   :9.260   Max.   :12.74   Max.   :12.500
#
# ...

# %% [markdown]
# ### 条形图

# %%
library(car)

barplot(table(Prestige$type),
        main="Bar Plot", 
        ylab="Freq",
        xlab="Occupation",
        col=c("blue", "red", "green"))
box()
# Out:
# Loading required package: carData
# Plot with title “Bar Plot”

# %% [markdown]
# 使用ggplot2画条形图

# %%
library(ggplot2)

ggplot(Prestige, aes(type)) + geom_bar()
# Out:
# plot without title

# %% [markdown]
# ggplot画条形图时候设置颜色

# %%
ggplot(Prestige, aes(type)) + geom_bar(fill=rainbow(4), color="black")
# Out:
# plot without title

# %%
hist(Prestige$income)
# Out:
# Plot with title “Histogram of Prestige$income”

# %%
par(mfrow=c(2,1))

hist(Prestige$income, breaks=seq(0,30000,1000), main="start at 0")

hist(Prestige$income, breaks=seq(500,30000,1000), main="start at 500")
# Out:
# Plot with title “start at 500”

# %%
library(foreign)

auto = read.dta("data/auto.dta")

par(mfrow=c(1,2))

hist(auto$length, breaks=5, main="5 bins")

hist(auto$length, breaks=20, main="20 bins")
# Out:
# Plot with title “20 bins”

# %%
library(MASS)

truehist(Prestige$income, nbins="FD")
# Out:
# plot without title

# %%
stem(Prestige$income)
# 茎1的叶接在茎0所有叶子的后面，茎3的叶接在茎2所有叶子的后面，以此类推
# Out:
#   The decimal point is 3 digit(s) to the right of the |
#
#    0 | 6979
#    2 | 44689001125556667999
#    4 | 012233456777881111234566889
#    6 | 01233556679901145679
#    8 | 000012334488999936
#   10 | 4004
#   12 | 45
#   14 | 026
#   16 | 5
#   18 | 3
#   20 |
#   22 |
#   24 | 39

# %%
stem(Prestige$income, scale=2)
# Out:
#   The decimal point is 3 digit(s) to the right of the |
#
#    0 | 69
#    1 | 79
#    2 | 44689
#    3 | 001125556667999
#    4 | 01223345677788
#    5 | 1111234566889
#    6 | 012335566799
#    7 | 01145679
#    8 | 0000123344889999
#    9 | 36
#   10 | 4
#   11 | 004
#   12 | 45
#   13 |
#   14 | 026
#   15 |
#   16 |
#   17 | 5
#   18 |
#   19 | 3
#   20 |
#   21 |
#   22 |
#   23 |
#   24 |
#   25 | 39

# %%
# kernel density plot
plot(density(Prestige$income),
     main="density plot of income")
# Out:
# Plot with title “density plot of income”

# %%
# overlay with histogram
# hist(Prestige$income, breaks=17, prob=TRUE, ylim=c(0,1.35e-4), main="Hist vs. density") 
hist(Prestige$income, breaks="FD",
     prob=TRUE,
     ylim=c(0, 1.35e-4),
     main="Hist vs. density")

lines(density(Prestige$income))

# box()
# Out:
# Plot with title “Hist vs. density”

# %%
# generate a random variable
set.seed(1000)
plot.ecdf(rnorm(80),verticals=T, cex=0.5, main="ECDF of a normal distribution sample")
#不光滑

curve(pnorm, add=T, col="red")
# Out:
# Plot with title “ECDF of a normal distribution sample”

# %%
# qq plot
set.seed(100)
x = rnorm(100, mean=50, sd=10)

qqPlot(x) # car
# Out:
# [1] 64 96
# plot without title

# %%
# qqplots of random variables governed by different distributions
set.seed(100)
qqPlot(rchisq(100, df=2))
# Out:
# [1] 38 77
# plot without title

# %%
# shape of distributions
x = seq(-4,4,by=0.01)
y1 = dnorm(x)
y2 = dchisq(x, df=2)

plot(y2~x, type="l")
lines(x, y1, col="red")
legend(2, 0.45, c("chisq","norm"),
       col=c("black","red"), lty=1)
# Out:
# plot without title

# %%
set.seed(20)

qqPlot(rnorm(500, mean=30, sd=10),
       distribution="t", df=3)
# Out:
# [1] 236   7
# plot without title

# %%
set.seed(17)
y = rt(100, df=2)
qqPlot(y)
# Out:
# [1] 55 66
# plot without title

# %%
x = seq(-4,4,by=0.01)
y1 = dnorm(x)
y2 = dt(x, df=2)

plot(y1~x, type="l")

lines(x, y2, col="red")

legend(2, 0.38, c("t","norm"), col=c("red","black"), lty=1)
# Out:
# plot without title

# %%
# boxplots by groups
Boxplot(Prestige$income) # car
# Out:
# [1]  2 17 24 25 26
# plot without title

# %%
Boxplot(income ~ type,
        data=Prestige,
        main="Comparison of Income")
# Out:
# [1] "general.managers" "physicians"
# Plot with title “Comparison of Income”

# %%
Boxplot(interlocks~nation, Ornstein)
# Out:
# [1] "1"  "2"  "3"  "5"  "6"  "9"  "13" "27"
# plot without title

# %%
barplot(table(TitanicSurvival$survived, TitanicSurvival$passengerClass))
# Out:
# plot without title

# %%
# barplot of frequency
data(TitanicSurvival,package="carData")

barplot(with(TitanicSurvival,table(survived, passengerClass)),
        beside=TRUE,
        legend=TRUE,
        xlab="Class",
        ylab="Frequency")

box()
# Out:
# plot without title

# %%
library(ggplot2)
ggplot(TitanicSurvival, aes(survived)) + 
geom_bar(aes(fill= passengerClass), position = position_dodge())
# Out:
# plot without title

# %%
plot(Vocab$vocabulary, Vocab$education)
# Out:
# plot without title

# %%
# scatter plot
with(Vocab, plot(vocabulary, education))
# Out:
# plot without title

# %%
with(Vocab, plot(jitter(vocabulary, amount=0.5),
                 jitter(education, amount=0.5)))
# Out:
# plot without title

# %%
scatterplot(prestige ~ income, data=Prestige) # car
# Out:
# plot without title

# %%
scatterplot(infantMortality~ppgdp, data=UN)
# transformation of variables before plotting
# Out:
# plot without title

# %%
scatterplot(log(infantMortality)~log(ppgdp), data=UN)
# Out:
# plot without title

# %%
scatterplot(infantMortality~I(ppgdp^2 + ppgdp), data=UN)
# Out:
# plot without title

# %%
# scatter plot by groups
scatterplot(prestige ~ income | type, data = Prestige)
# Out:
# plot without title

# %%
# matrix of scatter plots
scatterplotMatrix(~income + education + prestige, data=Duncan)
# Out:
# plot without title

# %%
# 3-d scatter plots
library(rgl)
# plot3d(Prestige$income, Prestige$education, Prestige$prestige)
with(Prestige, plot3d(income, education, prestige))
# rgl.snapshot("plot3d.png")
